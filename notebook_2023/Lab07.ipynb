# %% [markdown]
# <a href="https://colab.research.google.com/github/hufsaim/T10306201/blob/master/notebook_2023/Lab07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m pip install pyradiomics

# %%
import radiomics
from radiomics import featureextractor
import matplotlib.pyplot as plt
import SimpleITK as sitk
import nibabel as nib
import pandas as pd

# %%
# First define the settings
settings = {}
settings['binWidth'] = 20
settings['sigma'] = [1]
settings['normalize']=True
settings['geometryTolerance']=1
# Instantiate the extractor
extractor = featureextractor.RadiomicsFeatureExtractor(**settings)  # ** 'unpacks' the dictionary in the function call
# Enable a filter (in addition to the 'Original' filter already enabled)
#extractor.enableImageTypeByName('LoG')
#extractor.enableImageTypeByName('Wavelet')
print('Extraction parameters:\n\t', extractor.settings)
print('Enabled filters:\n\t', extractor.enabledImagetypes)  # Still the default parameters
print('Enabled features:\n\t', extractor.enabledFeatures)  # Still the default parameters

# %%
h1 = nib.load('H_t1ce.nii.gz')
img = h1.get_fdata()
img.shape
# Out:
# (240, 240, 155)

# %%
h2 = nib.load('H_seg.nii.gz')
seg = h2.get_fdata()
seg.shape
# Out:
# (240, 240, 155)

# %%
image = sitk.GetImageFromArray(img)
mask = sitk.GetImageFromArray(seg)

# %%
features = extractor.execute(image,mask)

# %%
features
# Out:
# OrderedDict([('diagnostics_Versions_PyRadiomics', 'v3.0.1'),
#              ('diagnostics_Versions_Numpy', '1.23.5'),
#              ('diagnostics_Versions_SimpleITK', '2.3.1'),
#              ('diagnostics_Versions_PyWavelet', '1.4.1'),
#              ('diagnostics_Versions_Python', '3.10.12'),
#              ('diagnostics_Configuration_Settings',
#               {'minimumROIDimensions': 2,
#                'minimumROISize': None,
#                'normalize': True,
#                'normalizeScale': 1,
#                'removeOutliers': None,
#                'resampledPixelSpacing': None,
#                'interpolator': 'sitkBSpline',
#                'preCrop': False,
#                'padDistance': 5,
#                'distances': [1],
#                'force2D': False,
#                'force2Ddimension': 0,
#                'resegmentRange': None,
#                'label': 1,
#                'additionalInfo': True,
#                'binWidth': 20,
#                'sigma': [1],
#                'geometryTolerance': 1}),
#              ('diagnostics_Configuration_EnabledImageTypes', {'Original': {}}),
#              ('diagnostics_Image-original_Hash',
#               '9343bc53442ff0ce08467605f50c595da1abe7a5'),
#              ('diagnostics_Image-original_Dimensionality', '3D'),
#              ('diagnostics_Image-original_Spacing', (1.0, 1.0, 1.0)),
#              ('diagnostics_Image-original_Size', (155, 240, 240)),
#              ('diagnostics_Image-original_Mean', 80.95051624103942),
#              ('diagnostics_Image-original_Minimum', 0.0),
#              ('diagnostics_Image-original_Maximum', 1354.0),
#              ('diagnostics_Mask-original_Hash',
#               '529930af9bc2405cf1fcf05567aa2ef0879d5d3e'),
#              ('diagnostics_Mask-original_Spacing', (1.0, 1.0, 1.0)),
#              ('diagnostics_Mask-original_Size', (155, 240, 240)),
#              ('diagnostics_Mask-original_BoundingBox',
#               (83, 163, 146, 24, 17, 18)),
#              ('diagnostics_Mask-original_VoxelNum', 413),
#              ('diagnostics_Mask-original_VolumeNum', 18),
#              ('diagnostics_Mask-original_CenterOfMassIndex',
#               (96.05569007263922, 169.69733656174333, 155.11380145278451)),
#              ('diagnostics_Mask-original_CenterOfMass',
#               (96.05569007263922, 169.69733656174333, 155.11380145278451)),
#              ('original_shape_Elongation', 0.7705221899156938),
#              ('original_shape_Flatness', 0.4456204321340164),
#              ('original_shape_LeastAxisLength', 8.942992981667214),
#              ('original_shape_MajorAxisLength', 20.068633161276786),
#              ('original_shape_Maximum2DDiameterColumn', array(25.55386468)),
#              ('original_shape_Maximum2DDiameterRow', array(20.)),
#              ('original_shape_Maximum2DDiameterSlice', array(21.84032967)),
#              ('original_shape_Maximum3DDiameter', array(27.91057147)),
#              ('original_shape_MeshVolume', array(339.45833333)),
#              ('original_shape_MinorAxisLength', 15.463327172041701),
#              ('original_shape_Sphericity', array(0.32805883)),
#              ('original_shape_SurfaceArea', array(717.33723887)),
#              ('original_shape_SurfaceVolumeRatio', array(2.113182)),
#              ('original_shape_VoxelVolume', 413.0),
#              ('original_firstorder_10Percentile', array(1.77562534)),
#              ('original_firstorder_90Percentile', array(2.82470118)),
#              ('original_firstorder_Energy', array(2380.45306353)),
#              ('original_firstorder_Entropy', array(-3.2034265e-16)),
#              ('original_firstorder_InterquartileRange', array(0.50570836)),
#              ('original_firstorder_Kurtosis', array(2.68904265)),
#              ('original_firstorder_Maximum', array(3.33578941)),
#              ('original_firstorder_MeanAbsoluteDeviation', array(0.32453437)),
#              ('original_firstorder_Mean', array(2.36725539)),
#              ('original_firstorder_Median', array(2.44272998)),
#              ('original_firstorder_Minimum', array(1.31295599)),
#              ('original_firstorder_Range', array(2.02283342)),
#              ('original_firstorder_RobustMeanAbsoluteDeviation',
#               array(0.23277428)),
#              ('original_firstorder_RootMeanSquared', array(2.40079338)),
#              ('original_firstorder_Skewness', array(-0.49854264)),
#              ('original_firstorder_TotalEnergy', array(2380.45306353)),
#              ('original_firstorder_Uniformity', array(1.)),
#              ('original_firstorder_Variance', array(0.15991077)),
#              ('original_glcm_Autocorrelation', array(1.)),
#              ('original_glcm_ClusterProminence', array(0.)),
#              ('original_glcm_ClusterShade', array(0.)),
#              ('original_glcm_ClusterTendency', array(0.)),
#              ('original_glcm_Contrast', array(0.)),
#              ('original_glcm_Correlation', array(1.)),
#              ('original_glcm_DifferenceAverage', array(0.)),
#              ('original_glcm_DifferenceEntropy', array(-3.2034265e-16)),
#              ('original_glcm_DifferenceVariance', array(0.)),
#              ('original_glcm_Id', array(1.)),
#              ('original_glcm_Idm', array(1.)),
#              ('original_glcm_Idmn', array(1.)),
#              ('original_glcm_Idn', array(1.)),
#              ('original_glcm_Imc1', array(0.)),
#              ('original_glcm_Imc2', array(0.)),
#              ('original_glcm_InverseVariance', array(0.)),
#              ('original_glcm_JointAverage', array(1.)),
#              ('original_glcm_JointEnergy', array(1.)),
#              ('original_glcm_JointEntropy', array(-3.2034265e-16)),
#              ('original_glcm_MCC', array(1)),
#              ('original_glcm_MaximumProbability', array(1.)),
#              ('original_glcm_SumAverage', array(2.)),
#              ('original_glcm_SumEntropy', array(-3.2034265e-16)),
#              ('original_glcm_SumSquares', array(0.)),
#              ('original_gldm_DependenceEntropy', array(4.53691696)),
#              ('original_gldm_DependenceNonUniformity', array(18.97094431)),
#              ('original_gldm_DependenceNonUniformityNormalized',
#               array(0.04593449)),
#              ('original_gldm_DependenceVariance', array(39.98120409)),
#              ('original_gldm_GrayLevelNonUniformity', array(413.)),
#              ('original_gldm_GrayLevelVariance', array(0.)),
#              ('original_gldm_HighGrayLevelEmphasis', array(1.)),
#              ('original_gldm_LargeDependenceEmphasis', array(193.48910412)),
#              ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#               array(193.48910412)),
#              ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#               array(193.48910412)),
#              ('original_gldm_LowGrayLevelEmphasis', array(1.)),
#              ('original_gldm_SmallDependenceEmphasis', array(0.03988675)),
#              ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#               array(0.03988675)),
#              ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#               array(0.03988675)),
#              ('original_glrlm_GrayLevelNonUniformity', array(232.07692308)),
#              ('original_glrlm_GrayLevelNonUniformityNormalized', array(1.)),
#              ('original_glrlm_GrayLevelVariance', array(0.)),
#              ('original_glrlm_HighGrayLevelRunEmphasis', array(1.)),
#              ('original_glrlm_LongRunEmphasis', array(4.89225219)),
#              ('original_glrlm_LongRunHighGrayLevelEmphasis',
#               array(4.89225219)),
#              ('original_glrlm_LongRunLowGrayLevelEmphasis', array(4.89225219)),
#              ('original_glrlm_LowGrayLevelRunEmphasis', array(1.)),
#              ('original_glrlm_RunEntropy', array(1.72101271)),
#              ('original_glrlm_RunLengthNonUniformity', array(95.77039302)),
#              ('original_glrlm_RunLengthNonUniformityNormalized',
#               array(0.40487807)),
#              ('original_glrlm_RunPercentage', array(0.5619296)),
#              ('original_glrlm_RunVariance', array(1.55476417)),
#              ('original_glrlm_ShortRunEmphasis', array(0.64907387)),
#              ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#               array(0.64907387)),
#              ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#               array(0.64907387)),
#              ('original_glszm_GrayLevelNonUniformity', array(18.)),
#              ('original_glszm_GrayLevelNonUniformityNormalized', array(1.)),
#              ('original_glszm_GrayLevelVariance', array(0.)),
#              ('original_glszm_HighGrayLevelZoneEmphasis', array(1.)),
#              ('original_glszm_LargeAreaEmphasis', array(6401.38888889)),
#              ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#               array(6401.38888889)),
#              ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#               array(6401.38888889)),
#              ('original_glszm_LowGrayLevelZoneEmphasis', array(1.)),
#              ('original_glszm_SizeZoneNonUniformity', array(4.)),
#              ('original_glszm_SizeZoneNonUniformityNormalized',
#               array(0.22222222)),
#              ('original_glszm_SmallAreaEmphasis', array(0.4451611)),
#              ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#               array(0.4451611)),
#              ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#               array(0.4451611)),
#              ('original_glszm_ZoneEntropy', array(2.54985503)),
#              ('original_glszm_ZonePercentage', array(0.04358354)),
#              ('original_glszm_ZoneVariance', array(5874.94135802)),
#              ('original_ngtdm_Busyness', array(0.)),
#              ('original_ngtdm_Coarseness', array(1000000.)),
#              ('original_ngtdm_Complexity', array(0.)),
#              ('original_ngtdm_Contrast', array(0.)),
#              ('original_ngtdm_Strength', array(0.))])

# %%
feature_names = list((filter(lambda k: k.startswith("original_"),features)))
feature_names

# %%
df1 = pd.DataFrame()
for j in range(len(feature_names)):
  print(j,feature_names[j],features[feature_names[j]])
  new_row = {"feature_name":feature_names[j], "H":features[feature_names[j]]}
  df1 = df1.append(new_row, ignore_index=True)

# %%
df1
# Out:
#                                feature_name                   H
# 0                 original_shape_Elongation            0.770522
# 1                   original_shape_Flatness             0.44562
# 2            original_shape_LeastAxisLength            8.942993
# 3            original_shape_MajorAxisLength           20.068633
# 4    original_shape_Maximum2DDiameterColumn  25.553864678361276
# ..                                      ...                 ...
# 102                 original_ngtdm_Busyness                 0.0
# 103               original_ngtdm_Coarseness           1000000.0
# 104               original_ngtdm_Complexity                 0.0
# 105                 original_ngtdm_Contrast                 0.0
# 106                 original_ngtdm_Strength                 0.0
#
# [107 rows x 2 columns]

# %%
df1.to_csv("H_features.csv")

# %%
h1 = nib.load('L_t1ce.nii.gz')
img = h1.get_fdata()
h2 = nib.load('L_seg.nii.gz')
seg = h2.get_fdata()
image = sitk.GetImageFromArray(img)
mask = sitk.GetImageFromArray(seg)
features = extractor.execute(image,mask)
feature_names = list((filter(lambda k: k.startswith("original_"),features)))
df2 = pd.DataFrame()
for j in range(len(feature_names)):
  print(j,feature_names[j],features[feature_names[j]])
  new_row = {"feature_name":feature_names[j], "L":features[feature_names[j]]}
  df2 = df2.append(new_row, ignore_index=True)
df2.to_csv("L_features.csv")

# %%
df2
# Out:
#                                feature_name                       L
# 0                 original_shape_Elongation                0.753312
# 1                   original_shape_Flatness                0.644358
# 2            original_shape_LeastAxisLength               37.575843
# 3            original_shape_MajorAxisLength               58.315163
# 4    original_shape_Maximum2DDiameterColumn       52.40229002629561
# ..                                      ...                     ...
# 102                 original_ngtdm_Busyness       0.798222117124707
# 103               original_ngtdm_Coarseness      0.3132429802778302
# 104               original_ngtdm_Complexity  0.00012759177185236363
# 105                 original_ngtdm_Contrast   1.576367046553807e-08
# 106                 original_ngtdm_Strength     0.25330706139189085
#
# [107 rows x 2 columns]

# %%
j = 4
df1.iloc[j,0],df1.iloc[j,1], df2.iloc[j,1]
# Out:
# ('original_shape_Maximum2DDiameterColumn',
#  array(25.55386468),
#  array(52.40229003))
